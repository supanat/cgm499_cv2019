# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("coins.png")
#img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
channels = cv2.split(img)
colors = ("b","g","r")

for (ch,color) in zip(channels,colors):
    hist = cv2.calcHist([ch],[0],None,[256],[0,256])
    plt.plot(hist,color=color)

# %%
img_gray =  cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray,cmap="gray")

# %%
hist = cv2.calcHist([img_gray],[0],None,[256],[0,256])
plt.xlabel("Bins")
plt.ylabel("# of Pixels")
plt.plot(hist)

# %%
(T,thresh) = cv2.threshold(img_gray,160,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh,cmap="gray")

# %%
mask = thresh
img_coins = img_gray.copy();
img_coins = cv2.bitwise_and(img_coins,img_coins,mask=mask)

# %%
plt.imshow(img_coins,cmap="gray")

# %%
plt.imshow(img_gray,cmap="gray")

# %%
img_blurred = cv2.GaussianBlur(img_gray,(5,5),5)
plt.imshow(img_blurred,cmap="gray")

# %%
hist = cv2.calcHist([img_blurred],[0],None,[256],[0,256])
plt.xlabel("Bins")
plt.ylabel("# of Pixels")
plt.plot(hist)

# %%
(T,thresh) = cv2.threshold(img_blurred,160,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh,cmap="gray")

# %%
mask = thresh
img_coins = img_gray.copy();
img_coins = cv2.bitwise_and(img_coins,img_coins,mask=mask)
plt.imshow(img_coins,cmap="gray")
