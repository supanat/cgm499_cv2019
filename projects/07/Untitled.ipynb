# %%
import cv2

import matplotlib.pyplot as plt

# %%
img = cv2.imread("parrot_2jpg.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (426, 640, 3)

# %%
plt.imshow(img)

# %%
src = img.copy()

# %%
px = img[50,50]
px
# Out:
# array([  0, 255,   0], dtype=uint8)

# %%
r,g,b = cv2.split(img)

# %%
r.shape
# Out:
# (426, 640)

# %%
r
# Out:
# array([[172, 177, 181, ..., 164, 152, 144],
#        [172, 175, 169, ..., 181, 171, 176],
#        [179, 175, 184, ..., 181, 199, 201],
#        ...,
#        [121, 128, 119, ..., 126, 112, 116],
#        [126, 123, 127, ..., 120, 112, 111],
#        [124, 123, 128, ..., 120, 115, 115]], dtype=uint8)

# %%
plt.imshow(r,cmap='gray')

# %%
img[50,50]
# Out:
# array([190, 143,  97], dtype=uint8)

# %%
print(img.item(50,50,0))
print(img.item(50,50,1))
print(img.item(50,50,2))
# Out:
# 145
# 144
# 162

# %%
img = src.copy()
img[50,50] = [0,255,0]
#img.itemset((50,50,0),0)
#img.itemset((50,50,1),255)
#img.itemset((50,50,2),0)
plt.imshow(img)
#print(img.item(50,50,0))
#print(img.item(50,50,1))
#print(img.item(50,50,2))
plt.savefig('output.jpg')

# %%
for i in range(200):
    img[50,i] = [255,0,0]
plt.imshow(img)
